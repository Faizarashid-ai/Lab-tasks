# %% [markdown]
# # **Table of Contents**
# *   Importing Libraries
# *   Data Understanding
# *   Data Preparation

# %% [markdown]
# ## Import Libraries
# Let's import some libraries to get started!

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Data Understanding
#
# *   Reading Data
# *   Dataframe shape
# *   Head and Tail
# *   Data Types
# *   Describe

# %% [markdown]
# **Reading Data**

# %%
train = pd.read_csv('titanic.csv')

# %%
heart= pd.read_csv('heart_disease.csv')

# %% [markdown]
# **Dataframe Shape**

# %%
train.shape
# Out:
# (891, 12)

# %%
heart.shape
# Out:
# (23496, 40)

# %% [markdown]
# **Head and Tail**

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
heart.head()
# Out:
#      State     Sex GeneralHealth  PhysicalHealthDays  MentalHealthDays  \
# 0  Alabama  Female     Very good                 0.0               0.0
# 1  Alabama  Female     Excellent                 0.0               0.0
# 2  Alabama  Female     Very good                 2.0               3.0
# 3  Alabama  Female     Excellent                 0.0               0.0
# 4  Alabama  Female          Fair                 2.0               0.0
#
#                                      LastCheckupTime PhysicalActivities  \
# 0  Within past year (anytime less than 12 months ...                 No
# 1                                                NaN                 No
# 2  Within past year (anytime less than 12 months ...                Yes
# 3  Within past year (anytime less than 12 months ...                Yes
# 4  Within past year (anytime less than 12 months ...                Yes
#
#    SleepHours RemovedTeeth HadHeartAttack  ... HeightInMeters  \
# ...

# %%
train.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
heart.tail()
# Out:
#           State     Sex GeneralHealth  PhysicalHealthDays  MentalHealthDays  \
# 23491  Arkansas    Male          Poor                30.0               0.0
# 23492  Arkansas  Female     Very good                 0.0               0.0
# 23493  Arkansas  Female     Very good                 0.0               0.0
# 23494  Arkansas  Female     Very good                 0.0               0.0
# 23495  Arkansas    Male          Good                30.0              30.0
#
#                                          LastCheckupTime PhysicalActivities  \
# 23491  Within past year (anytime less than 12 months ...                 No
# 23492  Within past year (anytime less than 12 months ...                 No
# 23493  Within past year (anytime less than 12 months ...                Yes
# 23494  Within past year (anytime less than 12 months ...                 No
# 23495  Within past year (anytime less than 12 months ...                 No
#
# ...

# %%
train.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
heart.columns
# Out:
# Index(['State', 'Sex', 'GeneralHealth', 'PhysicalHealthDays',
#        'MentalHealthDays', 'LastCheckupTime', 'PhysicalActivities',
#        'SleepHours', 'RemovedTeeth', 'HadHeartAttack', 'HadAngina',
#        'HadStroke', 'HadAsthma', 'HadSkinCancer', 'HadCOPD',
#        'HadDepressiveDisorder', 'HadKidneyDisease', 'HadArthritis',
#        'HadDiabetes', 'DeafOrHardOfHearing', 'BlindOrVisionDifficulty',
#        'DifficultyConcentrating', 'DifficultyWalking',
#        'DifficultyDressingBathing', 'DifficultyErrands', 'SmokerStatus',
#        'ECigaretteUsage', 'ChestScan', 'RaceEthnicityCategory', 'AgeCategory',
#        'HeightInMeters', 'WeightInKilograms', 'BMI', 'AlcoholDrinkers',
#        'HIVTesting', 'FluVaxLast12', 'PneumoVaxEver', 'TetanusLast10Tdap',
#        'HighRiskLastYear', 'CovidPos'],
#       dtype='object')

# %% [markdown]
# **Data Types**

# %%
train.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
heart.dtypes
# Out:
# State                         object
# Sex                           object
# GeneralHealth                 object
# PhysicalHealthDays           float64
# MentalHealthDays             float64
# LastCheckupTime               object
# PhysicalActivities            object
# SleepHours                   float64
# RemovedTeeth                  object
# HadHeartAttack                object
# HadAngina                     object
# HadStroke                     object
# HadAsthma                     object
# HadSkinCancer                 object
# HadCOPD                       object
# HadDepressiveDisorder         object
# HadKidneyDisease              object
# HadArthritis                  object
# HadDiabetes                   object
# DeafOrHardOfHearing           object
# BlindOrVisionDifficulty       object
# DifficultyConcentrating       object
# DifficultyWalking             object
# DifficultyDressingBathing     object
# DifficultyErrands             object
# ...

# %% [markdown]
# **Describe**

# %%
train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
heart.describe()
# Out:
#        PhysicalHealthDays  MentalHealthDays    SleepHours  HeightInMeters  \
# count        22786.000000       22895.00000  23185.000000    22190.000000
# mean             4.996621           4.50998      7.064352        1.702886
# std              9.324898           8.61258      1.573482        0.106540
# min              0.000000           0.00000      1.000000        0.910000
# 25%              0.000000           0.00000      6.000000        1.630000
# 50%              0.000000           0.00000      7.000000        1.700000
# 75%              5.000000           5.00000      8.000000        1.780000
# max             30.000000          30.00000     24.000000        2.260000
#
#        WeightInKilograms           BMI
# count       21603.000000  21252.000000
# mean           83.240412     28.585471
# std            21.423085      6.549223
# min            24.000000     12.500000
# 25%            68.040000     24.210000
# 50%            81.650000     27.440000
# ...

# %% [markdown]
# **Unique Values per Feature**

# %%
train.nunique()
# Out:
# PassengerId    891
# Survived         2
# Pclass           3
# Name           891
# Sex              2
# Age             88
# SibSp            7
# Parch            7
# Ticket         681
# Fare           248
# Cabin          147
# Embarked         3
# dtype: int64

# %%
heart.nunique()
# Out:
# State                           4
# Sex                             2
# GeneralHealth                   5
# PhysicalHealthDays             31
# MentalHealthDays               31
# LastCheckupTime                 4
# PhysicalActivities              2
# SleepHours                     22
# RemovedTeeth                    4
# HadHeartAttack                  2
# HadAngina                       2
# HadStroke                       2
# HadAsthma                       2
# HadSkinCancer                   2
# HadCOPD                         2
# HadDepressiveDisorder           2
# HadKidneyDisease                2
# HadArthritis                    2
# HadDiabetes                     4
# DeafOrHardOfHearing             2
# BlindOrVisionDifficulty         2
# DifficultyConcentrating         2
# DifficultyWalking               2
# DifficultyDressingBathing       2
# DifficultyErrands               2
# SmokerStatus                    4
# ECigaretteUsage                 4
# ...

# %% [markdown]
# **Unique values of a Single Feature**

# %%
train['Sex'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
heart['Sex'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %% [markdown]
# ##Univariate Analysis
# *   Categorical Features (Barchart, Piechart)
# *   Numerical Features (Histogram, Boxplot)

# %% [markdown]
# Let's check the frequency of survived and not survived people in the dataset.

# %%
sns.countplot(x='Survived',data=train,palette='rainbow')
# Out:
# <ipython-input-20-8a11688b9f87>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Survived',data=train,palette='rainbow')
# <Axes: xlabel='Survived', ylabel='count'>

# %%
sns.countplot(x='HadDiabetes',data=heart,palette='rainbow')
# Out:
# <ipython-input-21-f605740dd036>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='HadDiabetes',data=heart,palette='rainbow')
# <Axes: xlabel='HadDiabetes', ylabel='count'>

# %%
train['Sex'].value_counts().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
heart['Sex'].value_counts().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
sns.histplot(train['Age'],bins=30)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.histplot(heart['AgeCategory'],bins=30,color='pink')
# Out:
# <Axes: xlabel='AgeCategory', ylabel='Count'>

# %%
sns.histplot(train['Fare'],bins=27)
# Out:
# <Axes: xlabel='Fare', ylabel='Count'>

# %%
sns.histplot(heart['SleepHours'],bins=27, color='pink')
# Out:
# <Axes: xlabel='SleepHours', ylabel='Count'>

# %%
sns.histplot(train['Parch'])
# Out:
# <Axes: xlabel='Parch', ylabel='Count'>

# %%
sns.histplot(heart['WeightInKilograms'],color='red')
# Out:
# <Axes: xlabel='WeightInKilograms', ylabel='Count'>

# %%
sns.boxplot(train['Age'])
# Out:
# <Axes: ylabel='Age'>

# %%
sns.boxplot(heart['AgeCategory'],color='pink')
# Out:
# <Axes: ylabel='AgeCategory'>

# %% [markdown]
# ##Bivariate Analysis
# *   Categorical vs Categorical Features (Contingency Table etc.)
# *   Categorical vs Numerical Features (Box Plot, Histogram etc)
# *   Numerical vs Numerical Features (Scatter Plot etc)

# %%
# Create a contingency table (cross-tabulation) for Pclass and Survived
ct=pd.crosstab(train['Pclass'], train['Survived'])

# Plot the heatmap
#plt.figure(figsize=(8, 6))
sns.heatmap(ct,annot=True,fmt='d')
plt.title('Heatmap of Passenger Class vs Survival')
plt.xlabel('Survived')
plt.ylabel('Passenger Class')
plt.show()

# %%
# Create a contingency table (cross-tabulation) for Pclass and Survived
ct=pd.crosstab(heart['AgeCategory'], heart['SmokerStatus'])


sns.heatmap(ct,annot=True,fmt='d')
plt.title('Heatmap of Age Vs Smoker Status')
plt.xlabel('Smoker Status')
plt.ylabel('Age')
plt.show()

# %%
sns.countplot(x='Survived',hue='Sex',data=train)
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
sns.countplot(x='AgeCategory',hue='Sex',data=heart)
# Out:
# <Axes: xlabel='AgeCategory', ylabel='count'>

# %%
sns.countplot(x='Survived',hue='Pclass',data=train)
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
sns.countplot(x='Sex',hue='SmokerStatus',data=heart)
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
sns.boxplot(x='Pclass', y='Age', data=train)
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %%
sns.boxplot(x='HadDiabetes', y='AgeCategory', data=heart, color='pink')
# Out:
# <Axes: xlabel='HadDiabetes', ylabel='AgeCategory'>

# %%
sns.scatterplot(x='Age', y='Fare', data=train)

# Add titles and alabels
plt.title('Scatterplot of Age vs Fare (Titanic Dataset)')
plt.xlabel('Age')
plt.ylabel('Fare')

# Show the plot
plt.show()

# %%
heart.head()
# Out:
#      State     Sex GeneralHealth  PhysicalHealthDays  MentalHealthDays  \
# 0  Alabama  Female     Very good                 0.0               0.0
# 1  Alabama  Female     Excellent                 0.0               0.0
# 2  Alabama  Female     Very good                 2.0               3.0
# 3  Alabama  Female     Excellent                 0.0               0.0
# 4  Alabama  Female          Fair                 2.0               0.0
#
#                                      LastCheckupTime PhysicalActivities  \
# 0  Within past year (anytime less than 12 months ...                 No
# 1                                                NaN                 No
# 2  Within past year (anytime less than 12 months ...                Yes
# 3  Within past year (anytime less than 12 months ...                Yes
# 4  Within past year (anytime less than 12 months ...                Yes
#
#    SleepHours RemovedTeeth HadHeartAttack  ... HeightInMeters  \
# ...

# %%
# Select only numerical columns for correlation analysis
numerical_features = train.select_dtypes(include=['float64', 'int64'])

# Compute the correlation matrix
correlation_matrix = numerical_features.corr()

# Set up the matplotlib figure
#plt.figure(figsize=(10, 8))

# Generate a heatmap
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap='coolwarm')

# Add titles and labels
plt.title('Correlation Matrix of Titanic Dataset Features')
plt.show()

# %%
# Select only numerical columns for correlation analysis
numerical_features = heart.select_dtypes(include=['float64', 'int64'])

# Compute the correlation matrix
correlation_matrix = numerical_features.corr()

# Generate a heatmap
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap='coolwarm')

# Add titles and labels
plt.title('Correlation Matrix of Heart Dataset Features')
plt.show()

# %% [markdown]
# ##Multivariate Analysis

# %%
sns.scatterplot(x='Age', y='Fare', hue='Pclass', data=train)
# Out:
# <Axes: xlabel='Age', ylabel='Fare'>

# %% [markdown]
# # **Pandas_Profiling**

# %%
## Pandas Profiling

# !pip install ydata-profiling # Install Library

import pandas as pd
from ydata_profiling import ProfileReport # Import Library


# Load the Titanic dataset
df=pd.read_csv('titanic.csv')

# Generate the profiling report
prof = ProfileReport(df)
prof.to_file(output_file='eda.html')
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 400.1/400.1 kB 7.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.5/296.5 kB 19.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 687.8/687.8 kB 25.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.4/105.4 kB 7.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.2/43.2 kB 2.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 77.9 MB/s eta 0:00:00
# ...
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27081 sha256=4457771dcc38ebd1e9bfaf8752a8f1edc6e6e773626df649763098f7493657d8
#   Stored in directory: /root/.cache/pip/wheels/8d/55/1a/19cd535375ed1ede0c996405ebffe34b196d78e2d9545723a2
# Successfully built htmlmin
# ...
#             <div>
#                 <ins><a href="https://ydata.ai/register">Upgrade to ydata-sdk</a></ins>
#                 <p>
# ...

# %%
## Pandas Profiling

# !pip install ydata-profiling # Install Library

import pandas as pd
from ydata_profiling import ProfileReport # Import Library


# Load the Titanic dataset
df=pd.read_csv('heart_disease.csv')

# Generate the profiling report
prof = ProfileReport(df)
prof.to_file(output_file='eda.html')
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# ##Data Preparation
#
# *   Data Imputation
# *   Feature Encoding
# *   Identifying duplicated columns
# *   Dropping irrelevant columns and rows
# *   Renaming Columns

# %% [markdown]
# ## Data Imputation
# We want to fill in missing age data instead of just dropping the missing age data rows. One way to do this is by filling in the mean age of all the passengers (imputation).
# However we can be smarter about this and check the average age by passenger class. For example:

# %%
train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
heart.isnull().sum()
# Out:
# State                            0
# Sex                              0
# GeneralHealth                  411
# PhysicalHealthDays            3902
# MentalHealthDays              3113
# LastCheckupTime               2820
# PhysicalActivities             438
# SleepHours                    1877
# RemovedTeeth                  4797
# HadHeartAttack                1133
# HadAngina                     1620
# HadStroke                      578
# HadAsthma                      651
# HadSkinCancer                 1191
# HadCOPD                        814
# HadDepressiveDisorder          995
# HadKidneyDisease               683
# HadArthritis                   892
# HadDiabetes                    428
# DeafOrHardOfHearing           7248
# BlindOrVisionDifficulty       7573
# DifficultyConcentrating       8519
# DifficultyWalking             8508
# DifficultyDressingBathing     8447
# DifficultyErrands             9040
# SmokerStatus                 12535
# ECigaretteUsage              12624
# ...

# %%
train.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
heart.isnull()
# Out:
#         State    Sex  GeneralHealth  PhysicalHealthDays  MentalHealthDays  \
# 0       False  False          False               False             False
# 1       False  False          False               False             False
# 2       False  False          False               False             False
# 3       False  False          False               False             False
# 4       False  False          False               False             False
# ...       ...    ...            ...                 ...               ...
# 150673  False  False          False               False             False
# 150674  False  False          False               False             False
# 150675  False  False          False               False             False
# 150676  False  False          False               False             False
# 150677  False  False          False               False             False
#
#         LastCheckupTime  PhysicalActivities  SleepHours  RemovedTeeth  \
# ...

# %%
sns.heatmap(train.isnull(),cmap='viridis')
# Out:
# <Axes: >

# %%
sns.heatmap(heart.isnull(),cmap='viridis')
# Out:
# <Axes: >

# %%
mean_values = train.groupby('Pclass')['Age'].mean()
print(mean_values)
# Out:
# Pclass
# 1    38.233441
# 2    29.877630
# 3    25.140620
# Name: Age, dtype: float64

# %% [markdown]
# We can see the wealthier passengers in the higher classes tend to be older, which makes sense. We'll use these average age values to impute based on Pclass for Age.

# %%
def impute_age(cols):
    Age = cols[0]
    Pclass = cols[1]

    if pd.isnull(Age):

        if Pclass == 1:
            return 37

        elif Pclass == 2:
            return 29

        else:
            return 24

    else:
        return Age

# %%
def impute_age(cols):
    AgeCategory = cols[0]
    SleepHours = cols[1]

    if pd.isnull(AgeCategory):

        if SleepHours == 1:
            return 37

        elif SleepHours == 2:
            return 29

        else:
            return 24

    else:
        return AgeCategory

# %% [markdown]
# Now apply that function!

# %%
train[['Age','Pclass']].apply(impute_age,axis=1)
# Out:
# <ipython-input-67-a4f37ee6bb59>:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   AgeCategory = cols[0]
# <ipython-input-67-a4f37ee6bb59>:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   SleepHours = cols[1]
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888    24.0
# 889    26.0
# 890    32.0
# Length: 891, dtype: float64

# %%
heart[['AgeCategory','SmokerStatus']].apply(impute_age,axis=1)
# Out:
# <ipython-input-67-a4f37ee6bb59>:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   AgeCategory = cols[0]
# <ipython-input-67-a4f37ee6bb59>:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   SleepHours = cols[1]
# 0         Age 80 or older
# 1         Age 80 or older
# 2            Age 55 to 59
# 3                      24
# 4            Age 40 to 44
#                ...
# 150673       Age 40 to 44
# 150674       Age 65 to 69
# 150675       Age 50 to 54
# 150676       Age 65 to 69
# 150677                  A
# Length: 150678, dtype: object

# %% [markdown]
# Now let's check that heat map again!

# %%
sns.heatmap(train.isnull(),cmap='viridis')
# Out:
# <Axes: >

# %%
sns.heatmap(heart.isnull(),cmap='viridis')

# %% [markdown]
# **Identifying Duplicated Columns**

# %%
heart.loc[heart.duplicated()]
# Out:
#          State     Sex GeneralHealth  PhysicalHealthDays  MentalHealthDays  \
# 7310    Alaska    Male     Very good                 0.0               0.0
# 11503  Arizona  Female     Excellent                 0.0               0.0
#
#                                          LastCheckupTime PhysicalActivities  \
# 7310   Within past year (anytime less than 12 months ...                Yes
# 11503  Within past year (anytime less than 12 months ...                Yes
#
#        SleepHours  RemovedTeeth HadHeartAttack  ... HeightInMeters  \
# 7310          7.0  None of them             No  ...            NaN
# 11503         7.0  None of them             No  ...           1.63
#
#       WeightInKilograms    BMI AlcoholDrinkers HIVTesting FluVaxLast12  \
# 7310                NaN    NaN             NaN        NaN          NaN
# 11503              56.7  21.46             Yes         No          Yes
#
#       PneumoVaxEver   TetanusLast10Tdap HighRiskLastYear CovidPos
# ...

# %%
train.loc[train.duplicated()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
heart.drop(['HadAsthma','PhysicalActivities','GeneralHealth'],axis=1,inplace=True)

# %%
train.shape
# Out:
# (891, 8)

# %%
heart.shape
# Out:
# (23496, 37)

# %%
train.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Fare'],
#       dtype='object')

# %%
heart.columns
# Out:
# Index(['State', 'Sex', 'PhysicalHealthDays', 'MentalHealthDays',
#        'LastCheckupTime', 'SleepHours', 'RemovedTeeth', 'HadHeartAttack',
#        'HadAngina', 'HadStroke', 'HadSkinCancer', 'HadCOPD',
#        'HadDepressiveDisorder', 'HadKidneyDisease', 'HadArthritis',
#        'HadDiabetes', 'DeafOrHardOfHearing', 'BlindOrVisionDifficulty',
#        'DifficultyConcentrating', 'DifficultyWalking',
#        'DifficultyDressingBathing', 'DifficultyErrands', 'SmokerStatus',
#        'ECigaretteUsage', 'ChestScan', 'RaceEthnicityCategory', 'AgeCategory',
#        'HeightInMeters', 'WeightInKilograms', 'BMI', 'AlcoholDrinkers',
#        'HIVTesting', 'FluVaxLast12', 'PneumoVaxEver', 'TetanusLast10Tdap',
#        'HighRiskLastYear', 'CovidPos'],
#       dtype='object')

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare
# 0            1         0       3    male  22.0      1      0   7.2500
# 1            2         1       1  female  38.0      1      0  71.2833
# 2            3         1       3  female  26.0      0      0   7.9250
# 3            4         1       1  female  35.0      1      0  53.1000
# 4            5         0       3    male  35.0      0      0   8.0500

# %%
heart.head()
# Out:
#      State     Sex  PhysicalHealthDays  MentalHealthDays  \
# 0  Alabama  Female                 0.0               0.0
# 1  Alabama  Female                 0.0               0.0
# 2  Alabama  Female                 2.0               3.0
# 3  Alabama  Female                 0.0               0.0
# 4  Alabama  Female                 2.0               0.0
#
#                                      LastCheckupTime  SleepHours RemovedTeeth  \
# 0  Within past year (anytime less than 12 months ...         8.0          NaN
# 1                                                NaN         6.0          NaN
# 2  Within past year (anytime less than 12 months ...         5.0          NaN
# 3  Within past year (anytime less than 12 months ...         7.0          NaN
# 4  Within past year (anytime less than 12 months ...         9.0          NaN
#
#   HadHeartAttack HadAngina HadStroke  ... HeightInMeters WeightInKilograms  \
# ...

# %% [markdown]
# ##Feature Encoding

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Sex          891 non-null    object
#  4   Age          714 non-null    float64
#  5   SibSp        891 non-null    int64
#  6   Parch        891 non-null    int64
#  7   Fare         891 non-null    float64
# dtypes: float64(2), int64(5), object(1)
# memory usage: 55.8+ KB

# %%
heart.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23496 entries, 0 to 23495
# Data columns (total 37 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   State                      23496 non-null  object
#  1   Sex                        23496 non-null  object
#  2   PhysicalHealthDays         22786 non-null  float64
#  3   MentalHealthDays           22895 non-null  float64
#  4   LastCheckupTime            22990 non-null  object
#  5   SleepHours                 23185 non-null  float64
#  6   RemovedTeeth               21634 non-null  object
#  7   HadHeartAttack             23269 non-null  object
#  8   HadAngina                  23199 non-null  object
#  9   HadStroke                  23385 non-null  object
#  10  HadSkinCancer              23296 non-null  object
#  11  HadCOPD                    23360 non-null  object
#  12  HadDepressiveDisorder      23326 non-null  object
# ...

# %%
sex = pd.get_dummies(train['Sex'])

# %%
sex = pd.get_dummies(heart['Sex'])

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare
# 0            1         0       3    male  22.0      1      0   7.2500
# 1            2         1       1  female  38.0      1      0  71.2833
# 2            3         1       3  female  26.0      0      0   7.9250
# 3            4         1       1  female  35.0      1      0  53.1000
# 4            5         0       3    male  35.0      0      0   8.0500

# %%
heart.head()
# Out:
#      State     Sex  PhysicalHealthDays  MentalHealthDays  \
# 0  Alabama  Female                 0.0               0.0
# 1  Alabama  Female                 0.0               0.0
# 2  Alabama  Female                 2.0               3.0
# 3  Alabama  Female                 0.0               0.0
# 4  Alabama  Female                 2.0               0.0
#
#                                      LastCheckupTime  SleepHours RemovedTeeth  \
# 0  Within past year (anytime less than 12 months ...         8.0          NaN
# 1                                                NaN         6.0          NaN
# 2  Within past year (anytime less than 12 months ...         5.0          NaN
# 3  Within past year (anytime less than 12 months ...         7.0          NaN
# 4  Within past year (anytime less than 12 months ...         9.0          NaN
#
#   HadHeartAttack HadAngina HadStroke  ... HeightInMeters WeightInKilograms  \
# ...

# %% [markdown]
# # Lab Task
#
# Perform the steps mentioned above on the following dataset.
#
# https://www.kaggle.com/datasets/kamilpytlak/personal-key-indicators-of-heart-disease
